# %% [markdown]
# # Automatas celulares elementales

# %%
import automatas as ac

# %%
m= ac.malla( 40, 30 )

# %% [markdown]
# ### Algunos ejemplos de autómatas

# %%
import random

reglas= [ random.randint(0,255) for _ in range( 10 ) ]

# %%
m.evolucionar( reglas[0] )
m.graficar( f"Regla {reglas[0]}" )

# %%
m.evolucionar( reglas[1] )
m.graficar( f"Regla {reglas[1]}" )

# %%
m.evolucionar( reglas[2] )
m.graficar( f"Regla {reglas[2]}" )

# %%
m.evolucionar( reglas[3] )
m.graficar( f"Regla {reglas[3]}" )

# %%
m.evolucionar( reglas[4] )
m.graficar( f"Regla {reglas[4]}" )

# %%
m.evolucionar( reglas[5] )
m.graficar( f"Regla {reglas[5]}" )

# %%
m.evolucionar( reglas[6] )
m.graficar( f"Regla {reglas[6]}" )

# %%
m.evolucionar( reglas[7] )
m.graficar( f"Regla {reglas[7]}" )

# %%
m.evolucionar( reglas[8] )
m.graficar( f"Regla {reglas[8]}" )

# %%
m.evolucionar( reglas[9] )
m.graficar( f"Regla {reglas[9]}" )
